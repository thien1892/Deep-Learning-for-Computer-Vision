# %% [markdown]
# <a href="https://colab.research.google.com/github/thien1892/Deep-Learning-for-Computer-Vision/blob/main/Load_and_handle_image_data_directly_using_the_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
keras = tf.keras

# %% [markdown]
# # 1.  How to Load an Image with Keras

# %%
# load image from internet
from urllib.request import urlretrieve
URL = 'http://dulichvietnam.com.vn/data/hinh-anh-viet-nam-1.jpg'
urlretrieve(URL, '/content/nrvm.jpg')

# Open image
import PIL.Image as Image
Image.open('/content/nrvm.jpg').resize((224,224))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3E430A5D10>

# %%
# example of loading an image with the Keras API
from keras.preprocessing.image import load_img
# load the image
img = load_img('nrvm.jpg')
# report details about the image
print(type(img))
print(img.format)
print(img.mode)
print(img.size)
# show the image
img.show()
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (800, 396)

# %% [markdown]
# # 2.How to Convert an Image With Keras

# %%
# example of converting an image with the Keras API
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
# load the image
img = load_img('nrvm.jpg')
print(type(img))
# convert to numpy array
img_array = img_to_array(img)
print(img_array.dtype)
print(img_array.shape)
# convert back to image
img_pil = array_to_img(img_array)
print(type(img))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# float32
# (396, 800, 3)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %% [markdown]
# # 3.How to Save an Image With Kera

# %%
# example of saving an image with the Keras API
from keras.preprocessing.image import load_img
from keras.preprocessing.image import save_img
from keras.preprocessing.image import img_to_array
# load image as as grayscale
img = load_img('nrvm.jpg', color_mode='grayscale')
# convert image to a numpy array
img_array = img_to_array(img)
# save the image with a new filename
save_img('nrvm_den_trang.jpg', img_array)
# load the image to confirm it was saved correctly
img = load_img('nrvm_den_trang.jpg')
print(type(img))
print(img.format)
print(img.mode)
print(img.size)
img.show()
Image.open('nrvm_den_trang.jpg').resize((224,224))
# Out:
# <class 'PIL.Image.Image'>
# None
# RGB
# (800, 396)
# <PIL.Image.Image image mode=L size=224x224 at 0x7F3E41506D10>

# %% [markdown]
# # 4. Get file from internet and load in Keras

# %%
URL = 'http://dulichvietnam.com.vn/data/hinh-anh-viet-nam-1.jpg'
img = keras.utils.get_file('nui_rung.jpg', URL)
img = load_img(img)
print(type(img))
print(img.format)
print(img.mode)
print(img.size)
img.show()
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (800, 396)
