# %% [markdown]
# <a href="https://colab.research.google.com/github/thien1892/Deep-Learning-for-Computer-Vision/blob/main/1_1_How_to_Load_and_Manipulate_Images_With_PIL_Pillow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Load and Manipulate Images With PIL/Pillow
# # 1.How to Load and Display Images

# %%
# load image from internet
from urllib.request import urlretrieve
URL = 'http://dulichvietnam.com.vn/data/hinh-anh-viet-nam-1.jpg'
urlretrieve(URL, '/content/nrvm.jpg')

# Open image
import PIL.Image as Image
Image.open('/content/nrvm.jpg').resize((224,224))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FCE45FEDB90>

# %%
# load and show an image with Pillow
from PIL import Image
# load the image
image = Image.open('/content/nrvm.jpg')
# summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
# show the image
image.resize((224,224))
# Out:
# JPEG
# RGB
# (800, 396)
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FCE3F7307D0>

# %% [markdown]
# # 2.How to Convert Images to NumPy Arrays and Back

# %%
# load and display an image with Matplotlib
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
data = image.imread('/content/nrvm.jpg')
# summarize shape of the pixel array
print(data.dtype)
print(data.shape)
# display the array of pixels as an image
pyplot.imshow(data)
pyplot.show()
# Out:
# uint8
# (396, 800, 3)

# %%
# load image and convert to and from NumPy array
from PIL import Image
from numpy import asarray
# load the image
image = Image.open('/content/nrvm.jpg')
# convert image to numpy array
data = asarray(image)
# summarize shape
print(data.shape)
# create Pillow image
image2 = Image.fromarray(data)
# summarize image details
print(image2.format)
print(image2.mode)
print(image2.size)
# Out:
# (396, 800, 3)
# None
# RGB
# (800, 396)

# %% [markdown]
# # 3. How to Save Images to File

# %%
# example of saving an image in another format
from PIL import Image
# load the image
image = Image.open('/content/nrvm.jpg')
# save as PNG format
image.save('/content/nrvm_save.jpg', format='PNG')
# load the image again and inspect the format
image2 = Image.open('/content/nrvm_save.jpg')
print(image2.format)
# Out:
# PNG

# %%
# example of saving a grayscale version of a loaded image
from PIL import Image
# load the image
image = Image.open('/content/nrvm.jpg')
# convert the image to grayscale
gs_image = image.convert(mode='L')
# save in jpeg format
gs_image.save('/content/nrvm_grayscale.jpg')
# load the image again and show it
image2 = Image.open('/content/nrvm_grayscale.jpg')
# show the image
image2.resize((224,224))
# Out:
# <PIL.Image.Image image mode=L size=224x224 at 0x7FCE3F697310>

# %% [markdown]
# # 4. How to Flip, Rotate, and Crop Images

# %%
# create flipped versions of an image
from PIL import Image
from matplotlib import pyplot
pyplot.figure(figsize=(15,8))

# load image
image = Image.open('nrvm.jpg')
# horizontal flip
hoz_flip = image.transpose(Image.FLIP_LEFT_RIGHT)
# vertical flip
ver_flip = image.transpose(Image.FLIP_TOP_BOTTOM)
# plot all three images using matplotlib
pyplot.subplot(131)
pyplot.imshow(image)
pyplot.subplot(132)
pyplot.imshow(hoz_flip)
pyplot.subplot(133)
pyplot.imshow(ver_flip)
pyplot.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# create rotated versions of an image
from PIL import Image
from matplotlib import pyplot

pyplot.figure(figsize=(15,8))
# load image
image = Image.open('nrvm.jpg')
# plot original image
pyplot.subplot(131)
pyplot.imshow(image)
# rotate 45 degrees
pyplot.subplot(132)
pyplot.imshow(image.rotate(45))
# rotate 90 degrees
pyplot.subplot(133)
pyplot.imshow(image.rotate(90))
pyplot.show()

# %%
# example of cropping an image
from PIL import Image
# load image
image = Image.open('nrvm.jpg')
# create a cropped image
cropped = image.crop((100, 100, 200, 200))
# show cropped image
cropped
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FCE3F672050>
